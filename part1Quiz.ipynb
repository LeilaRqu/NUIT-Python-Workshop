# %% [markdown]
# # Part 1 Quiz

# %% [markdown]
# The quiz is short and combines topics covered in Part 1. If you are struggling, go back through the lecture notebook to review. The quiz is designed to test how well you're learning to put code together more than just if you remember the right operators and functions, so don't be ashamed to look things up. Try to spend as much time as you can to figure out a correct answer before you look at the answer key.
# <br><br>The quiz is self-graded - you do not need to turn anything in! The answer key is called "part1Quiz-answers.ipynb".

# %% [markdown]
# 1. Create a variable called `cube` that stores the value of 9 raised to the power of 3. Then write code to print `cube`:

# %%
cube = 9**3
print(cube)
# Out:
# 729

# %% [markdown]
# 2. Write code to change the variable `birthday` to a string:

# %%
birthday = 12071989
birthday_string = str(birthday)
print(birthday_string)
# Out:
# 12071989

# %% [markdown]
# 3. Would the following code evaluate to True or False?
# <br>`not 4 == 4 or not 4 < 5`
#
# False

# %%
not 4 == 4 or not 4 < 5
# Out:
# False

# %% [markdown]
# 4. In one year, I eat 27 apples. Write code to calculate how many apples I eat in 40 years, and round the answer to the closest hundred apples.

# %%
round(27*40, -2)
# Out:
# 1100

# %% [markdown]
# 5. Write code to create a new string that combines line_1 and line_2 with a new line character in the middle:

# %%
line_1 = "Hold fast to dreams"
line_2 = "For if dreams die"
new_string = line_1 + '\n' + line_2
print(new_string)
# Out:
# Hold fast to dreams
# For if dreams die

# %% [markdown]
# 6. Write code to index the substring "midnight" from the following string:

# %%
raven = "Once upon a midnight dreary,"
raven.index('midnight')
substring = raven[12:20]
print(substring)
# Out:
# midnight

# %%
raven = "Once upon a midnight dreary,"
midnight_start = raven.find('midnight')
midnight_end = midnight_start + len('midnight')
substring = raven[midnight_start:midnight_end]
print(substring)
# Out:
# midnight

# %% [markdown]
# 7. In one line of code, remove the question mark from the end of this sentence and change the sentence to capitalize only the first letter of the sentence:

# %%
sentence = "THIS IS THE LAST QUESTION?"
new_sentence = sentence.replace('?', '').capitalize()
print(new_sentence)
# Out:
# This is the last question
